# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %%
from google_play_scraper import Sort, reviews, app
import pandas as pd
import numpy as np

# %%
result, continuation_token = reviews(
    'com.codemasters.F1Mobile',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=1000,
    filter_score_with=None
)

# %%
data = pd.DataFrame(np.array(result), columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))

# %%
data
# Out:
#                                  reviewId                  userName  \
# 0    7bcb1718-541a-4966-aea6-f456767df9f4    Naufal Dimas Syahputra
# 1    996fc93c-0c95-4686-9200-21c9fcbfd693         muhammad nur riva
# 2    82fb219a-f289-415d-aeab-42346d65db92            Najib Muttakin
# 3    3f6c69d9-fea7-4d34-8e8c-e7cfc4f49b2e               Yudhi lieka
# 4    f8b2c9ae-f9ff-4379-9b61-431cacefa2ad            Joevan Maulana
# ..                                    ...                       ...
# 995  4e479ab7-a20f-4d1b-92e8-5362b8f5af12        Ryan Pratama Putra
# 996  95201192-b7bf-4b36-9024-b3fb699f6750           Victor Parasian
# 997  5c5b317e-90f1-48f1-b73c-f23f52d38c8b  Muhammad Dzaki Nurrohman
# 998  b41ab69f-aa81-4d63-a0d0-dc8c928ac89e                  VetroMax
# 999  f406b877-bb7c-4739-b3e4-0e08cb71ff9a      achmad zakiyah usman
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Settingan grafis high terlihat blur yang membu...      1            140
# 1    Jaringan nya berat banget serasa angkat dosa, ...      3              1
# 2    Sejak 2021 masalah kestabilan server dan konek...      3              9
# 3    Secara keseluruhan gameny seru tpi bugny parah...      2              2
# 4    Sering banget sinyal jelek padahal bagus....sa...      2              4
# ..                                                 ...    ...            ...
# 995  Bagus gamenya tapi harap diperbanyak lagi lap ...      5              0
# 996  Game nya sudah bagus, tapi sering ngelag, aduu...      3              1
# 997  Please developer untuk menambah sirkuit dan mo...      5             42
# 998  Good Game. Di aplikasi ini anda akan menjadi p...      4             45
# 999  Gamenya lumayan bagus sih, kalo bisa yg single...      4              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                 5.2.47 2023-09-01 13:27:37         None       NaT     5.2.47
# 1                 5.2.47 2023-09-23 18:07:25         None       NaT     5.2.47
# 2                 5.2.47 2023-09-18 10:05:48         None       NaT     5.2.47
# 3                 5.2.47 2023-09-22 13:26:18         None       NaT     5.2.47
# 4                 5.2.47 2023-09-09 02:21:14         None       NaT     5.2.47
# ..                   ...                 ...          ...       ...        ...
# 995                4.1.8 2022-08-10 02:43:13         None       NaT      4.1.8
# 996               3.5.11 2022-04-22 16:33:55         None       NaT     3.5.11
# 997                2.7.6 2021-02-21 15:29:47         None       NaT      2.7.6
# 998                2.8.4 2021-08-12 00:24:44         None       NaT      2.8.4
# 999                2.2.2 2020-08-21 21:48:33         None       NaT      2.2.2
#
# [1000 rows x 11 columns]

# %%
display(data)
# Out:
#                                  reviewId                  userName  \
# 0    7bcb1718-541a-4966-aea6-f456767df9f4    Naufal Dimas Syahputra
# 1    996fc93c-0c95-4686-9200-21c9fcbfd693         muhammad nur riva
# 2    82fb219a-f289-415d-aeab-42346d65db92            Najib Muttakin
# 3    3f6c69d9-fea7-4d34-8e8c-e7cfc4f49b2e               Yudhi lieka
# 4    f8b2c9ae-f9ff-4379-9b61-431cacefa2ad            Joevan Maulana
# ..                                    ...                       ...
# 995  4e479ab7-a20f-4d1b-92e8-5362b8f5af12        Ryan Pratama Putra
# 996  95201192-b7bf-4b36-9024-b3fb699f6750           Victor Parasian
# 997  5c5b317e-90f1-48f1-b73c-f23f52d38c8b  Muhammad Dzaki Nurrohman
# 998  b41ab69f-aa81-4d63-a0d0-dc8c928ac89e                  VetroMax
# 999  f406b877-bb7c-4739-b3e4-0e08cb71ff9a      achmad zakiyah usman
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ALV-U...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a-/ALV-U...
# ..                                                 ...
# 995  https://play-lh.googleusercontent.com/a-/ALV-U...
# 996  https://play-lh.googleusercontent.com/a-/ALV-U...
# 997  https://play-lh.googleusercontent.com/a-/ALV-U...
# 998  https://play-lh.googleusercontent.com/a-/ALV-U...
# 999  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0    Settingan grafis high terlihat blur yang membu...      1            140
# 1    Jaringan nya berat banget serasa angkat dosa, ...      3              1
# 2    Sejak 2021 masalah kestabilan server dan konek...      3              9
# 3    Secara keseluruhan gameny seru tpi bugny parah...      2              2
# 4    Sering banget sinyal jelek padahal bagus....sa...      2              4
# ..                                                 ...    ...            ...
# 995  Bagus gamenya tapi harap diperbanyak lagi lap ...      5              0
# 996  Game nya sudah bagus, tapi sering ngelag, aduu...      3              1
# 997  Please developer untuk menambah sirkuit dan mo...      5             42
# 998  Good Game. Di aplikasi ini anda akan menjadi p...      4             45
# 999  Gamenya lumayan bagus sih, kalo bisa yg single...      4              0
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                 5.2.47 2023-09-01 13:27:37         None       NaT     5.2.47
# 1                 5.2.47 2023-09-23 18:07:25         None       NaT     5.2.47
# 2                 5.2.47 2023-09-18 10:05:48         None       NaT     5.2.47
# 3                 5.2.47 2023-09-22 13:26:18         None       NaT     5.2.47
# 4                 5.2.47 2023-09-09 02:21:14         None       NaT     5.2.47
# ..                   ...                 ...          ...       ...        ...
# 995                4.1.8 2022-08-10 02:43:13         None       NaT      4.1.8
# 996               3.5.11 2022-04-22 16:33:55         None       NaT     3.5.11
# 997                2.7.6 2021-02-21 15:29:47         None       NaT      2.7.6
# 998                2.8.4 2021-08-12 00:24:44         None       NaT      2.8.4
# 999                2.2.2 2020-08-21 21:48:33         None       NaT      2.2.2
#
# [1000 rows x 11 columns]

# %%
from google.colab import files
data.to_csv('review game F1.csv')
files.download('review game F1.csv')

data.to_excel('review game F1.xlsx')
files.download('review game F1.xlsx')
